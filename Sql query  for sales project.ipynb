# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
import pandas as pd
df= pd.read_excel("Sales_Data_10K.xlsx")
df.head()
# Out:
#     OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0  ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1  ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 2  ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3  ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 4  ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
#
#    SalesAmount  CostPrice  Profit Region    Segment    Team  \
# 0         1443      336.7   432.9  South  Corporate  Team A
# 1         2718      951.3   815.4   West  Corporate  Team C
# 2         1212      141.4   363.6  South  Corporate  Team D
# 3         5601     1306.9  1680.3  North  Wholesale  Team D
# 4         1310      183.4   393.0   West  Corporate  Team C
#
#        SalesExecutive
# 0   Sales Executive 1
# 1   Sales Executive 7
# 2  Sales Executive 34
# 3  Sales Executive 10
# 4   Sales Executive 6

# %%
import pandas as pd
from sqlalchemy import create_engine

excel_file ="Sales_Data_10K.xlsx"
df = pd.read_excel(excel_file)

print(df.head())

engine=create_engine(
"mysql+pymysql://root:2411@localhost/ri"
)


df.to_sql(
    name="sales",
    con=engine,
    if_exists="replace",
    index=False
)

print("excel data inserted successfully")
# Out:
#     OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0  ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1  ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 2  ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3  ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 4  ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
#
#    SalesAmount  CostPrice  Profit Region    Segment    Team  \
# 0         1443      336.7   432.9  South  Corporate  Team A
# 1         2718      951.3   815.4   West  Corporate  Team C
# 2         1212      141.4   363.6  South  Corporate  Team D
# 3         5601     1306.9  1680.3  North  Wholesale  Team D
# 4         1310      183.4   393.0   West  Corporate  Team C
#
#        SalesExecutive
# 0   Sales Executive 1
# 1   Sales Executive 7
# 2  Sales Executive 34
# 3  Sales Executive 10
# 4   Sales Executive 6
# ...

# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:2411@localhost/ri

# %%
import pandas as pd
from sqlalchemy import create_engine
engine=create_engine("mysql+pymysql://root:2411@localhost/ri")
df = pd.read_sql("SHOW TABLES",engine) 
df
# Out:
#   Tables_in_ri
# 0  application
# 1    companies
# 2   interviews
# 3          lcu
# 4         loke
# 5         loki
# 6        sales
# 7     students
# 8    students2

# %%
# %config sqlMagic.autopandas = False

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine(
    "mysql+pymysql://root:2411@localhost/ri"
)
tables = pd.read_sql("SHOW TABLES", engine)
print(tables)
# Out:
#   Tables_in_ri
# 0  application
# 1    companies
# 2   interviews
# 3          lcu
# 4         loke
# 5         loki
# 6        sales
# 7     students
# 8    students2

# %%
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
df = pd.read_sql("SELECT*FROM sales",engine)
df
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1     ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 2     ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3     ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 4     ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
# ...        ...        ...           ...         ...          ...       ...
# 9995  ORD09996 2023-12-07  Customer 168  Headphones  Accessories        10
# 9996  ORD09997 2023-12-03  Customer 221     Speaker  Accessories         5
# 9997  ORD09998 2024-01-28  Customer 114      Laptop  Electronics         5
# 9998  ORD09999 2023-06-25  Customer 257      Laptop  Electronics         6
# 9999  ORD10000 2023-08-21  Customer 500  Headphones  Accessories         4
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
pd.read_sql ("SELECT *FROM sales LIMIT 10",engine)
# Out:
#     OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0  ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1  ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 2  ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3  ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 4  ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
# 5  ORD00006 2023-03-19  Customer 123  Smartphone  Electronics         6
# 6  ORD00007 2023-08-29  Customer 169      Tablet  Electronics         6
# 7  ORD00008 2024-01-06  Customer 283     Monitor  Electronics         5
# 8  ORD00009 2023-08-26  Customer 276      Webcam  Accessories         7
# 9  ORD00010 2023-08-29  Customer 459      Tablet  Electronics         9
#
#    SalesAmount  CostPrice  Profit Region    Segment    Team  \
# 0         1443      336.7   432.9  South  Corporate  Team A
# ...

# %%
pd.read_sql("SELECT COUNT(*) AS total_rows FROM sales",engine)
# Out:
#    total_rows
# 0       10000

# %%
pd.read_sql("SELECT*FROM sales WHERE category ='Electronics'",engine)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1     ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 2     ORD00006 2023-03-19  Customer 123  Smartphone  Electronics         6
# 3     ORD00007 2023-08-29  Customer 169      Tablet  Electronics         6
# 4     ORD00008 2024-01-06  Customer 283     Monitor  Electronics         5
# ...        ...        ...           ...         ...          ...       ...
# 4102  ORD09990 2023-03-18   Customer 22      Tablet  Electronics         4
# 4103  ORD09993 2023-07-09  Customer 164      Laptop  Electronics         5
# 4104  ORD09995 2023-12-30   Customer 80      Tablet  Electronics         4
# 4105  ORD09998 2024-01-28  Customer 114      Laptop  Electronics         5
# 4106  ORD09999 2023-06-25  Customer 257      Laptop  Electronics         6
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
pd.read_sql("SELECT*FROM sales WHERE salesamount > 3000",engine)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 1     ORD00007 2023-08-29  Customer 169      Tablet  Electronics         6
# 2     ORD00009 2023-08-26  Customer 276      Webcam  Accessories         7
# 3     ORD00010 2023-08-29  Customer 459      Tablet  Electronics         9
# 4     ORD00012 2023-12-16  Customer 398  Smartphone  Electronics         8
# ...        ...        ...           ...         ...          ...       ...
# 6328  ORD09993 2023-07-09  Customer 164      Laptop  Electronics         5
# 6329  ORD09994 2023-03-13  Customer 425  Headphones  Accessories         6
# 6330  ORD09995 2023-12-30   Customer 80      Tablet  Electronics         4
# 6331  ORD09996 2023-12-07  Customer 168  Headphones  Accessories        10
# 6332  ORD09999 2023-06-25  Customer 257      Laptop  Electronics         6
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
pd.read_sql(""" SELECT COUNT(*) AS total_tables FROM information_schema.tables WHERE table_schema = 'ri';""",engine)
# Out:
#    total_tables
# 0             9

# %%
pd.read_sql("""
SELECT COUNT(*) AS total_rows
FROM sales;
""",engine)
# Out:
#    total_rows
# 0       10000

# %%
tables=pd.read_sql("""
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'ri';
""",engine)

print("total tables:",len(tables))
tables
# Out:
# total tables: 9
#     TABLE_NAME
# 0  application
# 1    companies
# 2   interviews
# 3          lcu
# 4         loke
# 5         loki
# 6        sales
# 7     students
# 8    students2

# %%
pd.read_sql("DESCRIBE sales;",engine)
# Out:
#              Field      Type Null Key Default Extra
# 0          OrderID      text  YES        None
# 1        OrderDate  datetime  YES        None
# 2     CustomerName      text  YES        None
# 3          Product      text  YES        None
# 4         Category      text  YES        None
# 5         Quantity    bigint  YES        None
# 6      SalesAmount    bigint  YES        None
# 7        CostPrice    double  YES        None
# 8           Profit    double  YES        None
# 9           Region      text  YES        None
# 10         Segment      text  YES        None
# 11            Team      text  YES        None
# 12  SalesExecutive      text  YES        None

# %%
pd.read_sql(""" SELECT column_name , data_type
FROM information_schema.columns
WHERE table_name = 'sales'
AND table_schema ='ri';
""",engine)
# Out:
#        COLUMN_NAME DATA_TYPE
# 0         Category      text
# 1        CostPrice    double
# 2     CustomerName      text
# 3        OrderDate  datetime
# 4          OrderID      text
# 5          Product      text
# 6           Profit    double
# 7         Quantity    bigint
# 8           Region      text
# 9      SalesAmount    bigint
# 10  SalesExecutive      text
# 11         Segment      text
# 12            Team      text

# %%
pd.read_sql(""" SELECT COUNT(*) AS total_tables
FROM information_schema.tables
WHERE table_schema ='ri';
""",engine)
# Out:
#    total_tables
# 0             9

# %%
pd.read_sql(""" select orderID,product,salesAmount from sales;""",engine)
# Out:
#        orderID     product  salesAmount
# 0     ORD00001  Smartphone         1443
# 1     ORD00002       Mouse         2718
# 2     ORD00003      Laptop         1212
# 3     ORD00004    Keyboard         5601
# 4     ORD00005    Keyboard         1310
# ...        ...         ...          ...
# 9995  ORD09996  Headphones        12980
# 9996  ORD09997     Speaker         2820
# 9997  ORD09998      Laptop         2585
# 9998  ORD09999      Laptop         4170
# 9999  ORD10000  Headphones         1968
#
# [10000 rows x 3 columns]

# %%
pd.read_sql("SELECT*FROM sales WHERE costprice > 500",engine)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 1     ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 2     ORD00007 2023-08-29  Customer 169      Tablet  Electronics         6
# 3     ORD00009 2023-08-26  Customer 276      Webcam  Accessories         7
# 4     ORD00010 2023-08-29  Customer 459      Tablet  Electronics         9
# ...        ...        ...           ...         ...          ...       ...
# 6564  ORD09991 2024-01-17  Customer 160  Headphones  Accessories         2
# 6565  ORD09993 2023-07-09  Customer 164      Laptop  Electronics         5
# 6566  ORD09994 2023-03-13  Customer 425  Headphones  Accessories         6
# 6567  ORD09995 2023-12-30   Customer 80      Tablet  Electronics         4
# 6568  ORD09996 2023-12-07  Customer 168  Headphones  Accessories        10
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
pd.read_sql("SELECT*FROM sales WHERE Region = 'North' and Team= 'Team A'",engine)
# Out:
#       OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0    ORD00022 2023-07-19  Customer 191       Mouse  Accessories         8
# 1    ORD00029 2023-12-20  Customer 157      Webcam  Accessories        10
# 2    ORD00036 2023-06-22  Customer 217      Laptop  Electronics         5
# 3    ORD00038 2023-05-07  Customer 411       Mouse  Accessories         6
# 4    ORD00043 2023-07-24   Customer 76       Mouse  Accessories         2
# ..        ...        ...           ...         ...          ...       ...
# 607  ORD09907 2024-02-05  Customer 288  Smartphone  Electronics         1
# 608  ORD09922 2023-09-04  Customer 180     Speaker  Accessories         6
# 609  ORD09934 2023-04-11  Customer 285      Laptop  Electronics         7
# 610  ORD09938 2023-10-27  Customer 392      Laptop  Electronics         8
# 611  ORD09947 2023-05-30  Customer 276      Tablet  Electronics         5
#
#      SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
pd.read_sql("SELECT*FROM sales WHERE Profit >100 ",engine)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1     ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 2     ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3     ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 4     ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
# ...        ...        ...           ...         ...          ...       ...
# 9724  ORD09996 2023-12-07  Customer 168  Headphones  Accessories        10
# 9725  ORD09997 2023-12-03  Customer 221     Speaker  Accessories         5
# 9726  ORD09998 2024-01-28  Customer 114      Laptop  Electronics         5
# 9727  ORD09999 2023-06-25  Customer 257      Laptop  Electronics         6
# 9728  ORD10000 2023-08-21  Customer 500  Headphones  Accessories         4
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
pd.read_sql(""" select orderID,product,CostPrice,Category,Profit,Quantity from sales;""",engine)
# Out:
#        orderID     product  CostPrice     Category  Profit  Quantity
# 0     ORD00001  Smartphone      336.7  Electronics   432.9         3
# 1     ORD00002       Mouse      951.3  Accessories   815.4         2
# 2     ORD00003      Laptop      141.4  Electronics   363.6         6
# 3     ORD00004    Keyboard     1306.9  Accessories  1680.3         3
# 4     ORD00005    Keyboard      183.4  Accessories   393.0         5
# ...        ...         ...        ...          ...     ...       ...
# 9995  ORD09996  Headphones      908.6  Accessories  3894.0        10
# 9996  ORD09997     Speaker      394.8  Accessories   846.0         5
# 9997  ORD09998      Laptop      361.9  Electronics   775.5         5
# 9998  ORD09999      Laptop      486.5  Electronics  1251.0         6
# 9999  ORD10000  Headphones      344.4  Accessories   590.4         4
#
# [10000 rows x 6 columns]

# %%
pd.read_sql(""" select product,CostPrice,Profit,Segment from sales;""",engine)
# Out:
#          product  CostPrice  Profit    Segment
# 0     Smartphone      336.7   432.9  Corporate
# 1          Mouse      951.3   815.4  Corporate
# 2         Laptop      141.4   363.6  Corporate
# 3       Keyboard     1306.9  1680.3  Wholesale
# 4       Keyboard      183.4   393.0  Corporate
# ...          ...        ...     ...        ...
# 9995  Headphones      908.6  3894.0     Retail
# 9996     Speaker      394.8   846.0  Wholesale
# 9997      Laptop      361.9   775.5     Retail
# 9998      Laptop      486.5  1251.0  Corporate
# 9999  Headphones      344.4   590.4  Wholesale
#
# [10000 rows x 4 columns]

# %%
pd.read_sql("SELECT*FROM sales WHERE SalesAmount > 500",engine)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1     ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 2     ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3     ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 4     ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
# ...        ...        ...           ...         ...          ...       ...
# 9500  ORD09996 2023-12-07  Customer 168  Headphones  Accessories        10
# 9501  ORD09997 2023-12-03  Customer 221     Speaker  Accessories         5
# 9502  ORD09998 2024-01-28  Customer 114      Laptop  Electronics         5
# 9503  ORD09999 2023-06-25  Customer 257      Laptop  Electronics         6
# 9504  ORD10000 2023-08-21  Customer 500  Headphones  Accessories         4
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
pd.read_sql(""" select product,CostPrice,Profit,SalesAmount from sales;""",engine)
# Out:
#          product  CostPrice  Profit  SalesAmount
# 0     Smartphone      336.7   432.9         1443
# 1          Mouse      951.3   815.4         2718
# 2         Laptop      141.4   363.6         1212
# 3       Keyboard     1306.9  1680.3         5601
# 4       Keyboard      183.4   393.0         1310
# ...          ...        ...     ...          ...
# 9995  Headphones      908.6  3894.0        12980
# 9996     Speaker      394.8   846.0         2820
# 9997      Laptop      361.9   775.5         2585
# 9998      Laptop      486.5  1251.0         4170
# 9999  Headphones      344.4   590.4         1968
#
# [10000 rows x 4 columns]

# %%
#find unique product categories

# %%
pd.read_sql(""" select DISTINCT Category from sales;""",engine)
# Out:
#       Category
# 0  Electronics
# 1  Accessories

# %%
#sort oreder by salaamount

# %%
 pd.read_sql(
     "SELECT * FROM Sales ORDER BY SalesAmount DESC ",
      engine
 )
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD07051 2023-05-12  Customer 221     Monitor  Electronics        10
# 1     ORD04924 2023-09-22  Customer 258  Smartphone  Electronics        10
# 2     ORD01446 2023-11-19  Customer 297  Headphones  Accessories        10
# 3     ORD06002 2024-01-22  Customer 400      Laptop  Electronics        10
# 4     ORD03890 2023-05-07  Customer 187       Mouse  Accessories        10
# ...        ...        ...           ...         ...          ...       ...
# 9995  ORD00408 2023-07-25  Customer 395  Smartphone  Electronics         1
# 9996  ORD09992 2023-09-04  Customer 387     Speaker  Accessories         1
# 9997  ORD05955 2023-09-11   Customer 78  Headphones  Accessories         1
# 9998  ORD01545 2023-04-24  Customer 495     Monitor  Electronics         1
# 9999  ORD00897 2023-05-13   Customer 43  Smartphone  Electronics         1
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
 pd.read_sql(
    "SELECT * FROM Sales ORDER BY SalesAmount DESC LIMIT 5",
    engine
)
# Out:
#     OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0  ORD07051 2023-05-12  Customer 221     Monitor  Electronics        10
# 1  ORD04924 2023-09-22  Customer 258  Smartphone  Electronics        10
# 2  ORD01446 2023-11-19  Customer 297  Headphones  Accessories        10
# 3  ORD06002 2024-01-22  Customer 400      Laptop  Electronics        10
# 4  ORD03890 2023-05-07  Customer 187       Mouse  Accessories        10
#
#    SalesAmount  CostPrice  Profit Region    Segment    Team  \
# 0        20000     1400.0  6000.0  North     Retail  Team A
# 1        19990     1399.3  5997.0  South  Wholesale  Team A
# 2        19970     1397.9  5991.0  North     Online  Team C
# 3        19960     1397.2  5988.0   East  Corporate  Team D
# 4        19960     1397.2  5988.0   East     Online  Team B
#
#        SalesExecutive
# 0   Sales Executive 1
# 1  Sales Executive 24
# 2   Sales Executive 5
# 3  Sales Executive 25
# 4  Sales Executive 45

# %%
#order between two dates
pd.read_sql(
    "SELECT * FROM Sales WHERE OrderDate BETWEEN '2023-01-01' AND '2024-12-31'",
    engine
)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1     ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 2     ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3     ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 4     ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
# ...        ...        ...           ...         ...          ...       ...
# 9995  ORD09996 2023-12-07  Customer 168  Headphones  Accessories        10
# 9996  ORD09997 2023-12-03  Customer 221     Speaker  Accessories         5
# 9997  ORD09998 2024-01-28  Customer 114      Laptop  Electronics         5
# 9998  ORD09999 2023-06-25  Customer 257      Laptop  Electronics         6
# 9999  ORD10000 2023-08-21  Customer 500  Headphones  Accessories         4
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#minimum sales amount
pd.read_sql(
    "SELECT MIN(SalesAmount) from Sales",
    engine
)
# Out:
#    MIN(SalesAmount)
# 0                53

# %%
#maxmum sales amount
pd.read_sql(
    "SELECT MAX(SalesAmount) from Sales",
    engine

)
# Out:
#    MAX(SalesAmount)
# 0             20000

# %%
#maxmum sales amount
pd.read_sql(
    "SELECT AVG(SalesAmount) from Sales",
    engine

)
# Out:
#    AVG(SalesAmount)
# 0         5640.2283

# %%
#order with quantity more than 5

#Average  sales amount
pd.read_sql(
    "SELECT *from Sales WHERE Quantity > 5",
    engine

)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 1     ORD00006 2023-03-19  Customer 123  Smartphone  Electronics         6
# 2     ORD00007 2023-08-29  Customer 169      Tablet  Electronics         6
# 3     ORD00009 2023-08-26  Customer 276      Webcam  Accessories         7
# 4     ORD00010 2023-08-29  Customer 459      Tablet  Electronics         9
# ...        ...        ...           ...         ...          ...       ...
# 4989  ORD09986 2023-09-03  Customer 295       Mouse  Accessories         9
# 4990  ORD09987 2023-08-06  Customer 450  Headphones  Accessories         8
# 4991  ORD09994 2023-03-13  Customer 425  Headphones  Accessories         6
# 4992  ORD09996 2023-12-07  Customer 168  Headphones  Accessories        10
# 4993  ORD09999 2023-06-25  Customer 257      Laptop  Electronics         6
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#Average  sales amount
pd.read_sql(
    "SELECT *from Sales WHERE CustomerName LIKE 'Customer 1%%'",
    engine

)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1     ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
# 2     ORD00006 2023-03-19  Customer 123  Smartphone  Electronics         6
# 3     ORD00007 2023-08-29  Customer 169      Tablet  Electronics         6
# 4     ORD00011 2023-09-13   Customer 15      Laptop  Electronics         9
# ...        ...        ...           ...         ...          ...       ...
# 2234  ORD09988 2023-03-24  Customer 124     Printer  Accessories         5
# 2235  ORD09991 2024-01-17  Customer 160  Headphones  Accessories         2
# 2236  ORD09993 2023-07-09  Customer 164      Laptop  Electronics         5
# 2237  ORD09996 2023-12-07  Customer 168  Headphones  Accessories        10
# 2238  ORD09998 2024-01-28  Customer 114      Laptop  Electronics         5
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
pd.read_sql(
    "SELECT * FROM Sales WHERE CustomerName LIKE 'Customer 1%%'",
    engine
)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1     ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
# 2     ORD00006 2023-03-19  Customer 123  Smartphone  Electronics         6
# 3     ORD00007 2023-08-29  Customer 169      Tablet  Electronics         6
# 4     ORD00011 2023-09-13   Customer 15      Laptop  Electronics         9
# ...        ...        ...           ...         ...          ...       ...
# 2234  ORD09988 2023-03-24  Customer 124     Printer  Accessories         5
# 2235  ORD09991 2024-01-17  Customer 160  Headphones  Accessories         2
# 2236  ORD09993 2023-07-09  Customer 164      Laptop  Electronics         5
# 2237  ORD09996 2023-12-07  Customer 168  Headphones  Accessories        10
# 2238  ORD09998 2024-01-28  Customer 114      Laptop  Electronics         5
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#total sales by region
pd.read_sql(
    "SELECT * FROM Sales WHERE Region = 'North'",
    engine
)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 1     ORD00006 2023-03-19  Customer 123  Smartphone  Electronics         6
# 2     ORD00018 2023-06-03  Customer 100      Tablet  Electronics         8
# 3     ORD00019 2024-01-30  Customer 154      Tablet  Electronics         9
# 4     ORD00022 2023-07-19  Customer 191       Mouse  Accessories         8
# ...        ...        ...           ...         ...          ...       ...
# 2494  ORD09976 2023-06-01  Customer 335     Speaker  Accessories         1
# 2495  ORD09977 2023-05-10  Customer 250      Tablet  Electronics         2
# 2496  ORD09980 2023-03-26  Customer 211       Mouse  Accessories         1
# 2497  ORD09983 2023-09-29  Customer 416     Monitor  Electronics         9
# 2498  ORD09989 2023-07-16  Customer 301     Printer  Accessories         2
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#total sales by region
pd.read_sql(
    "SELECT Region , SUM(SalesAmount) AS TotalSales From Sales GROUP BY Region",
    engine
)
# Out:
#   Region  TotalSales
# 0  South  14601838.0
# 1   West  13693083.0
# 2  North  13974387.0
# 3   East  14132975.0

# %%
#total profit by category
#total sales by region
pd.read_sql(
    "SELECT Category , SUM(Profit) AS Totalprofit From Sales GROUP BY Category ",
    engine
)
# Out:
#       Category  Totalprofit
# 0  Electronics    7046247.6
# 1  Accessories    9874437.3

# %%
#total profit by category
#total sales by region
pd.read_sql(
    "SELECT Category , SUM(SalesAmount) AS Totalprofit From Sales GROUP BY Category ",
    engine
)
# Out:
#       Category  Totalprofit
# 0  Electronics   23487492.0
# 1  Accessories   32914791.0

# %%
#average sales by segment

pd.read_sql(
    "SELECT Segment , AVG(SalesAmount) AS AvgSales From Sales GROUP BY Segment ",
    engine
)
# Out:
#      Segment   AvgSales
# 0  Corporate  5732.4998
# 1  Wholesale  5680.8530
# 2     Retail  5589.6090
# 3     Online  5561.6592

# %%
#number of ordrs per product

pd.read_sql(
    "SELECT Product ,COUNT(*) AS Ordercount From Sales GROUP BY Product ",
    engine
)
# Out:
#       Product  Ordercount
# 0  Smartphone        1023
# 1       Mouse         963
# 2      Laptop        1042
# 3    Keyboard         975
# 4      Tablet         980
# 5     Monitor        1062
# 6      Webcam        1010
# 7     Printer         998
# 8  Headphones         995
# 9     Speaker         952

# %%
#region with sales>100000
pd.read_sql(
    """SELECT Region, SUM(SalesAmount)  AS 
     Totalsales 
     From Sales
     GROUP BY Region
     HAVING SUM(SalesAmount) > 100000 """ ,
     engine
)
# Out:
#   Region  Totalsales
# 0  South  14601838.0
# 1   West  13693083.0
# 2  North  13974387.0
# 3   East  14132975.0

# %%
pd.read_sql(
    """
    SELECT Region,
           SUM(SalesAmount) AS TotalSales
    FROM Sales
    GROUP BY Region
    """,
    engine
)
# Out:
#   Region  TotalSales
# 0  South  14601838.0
# 1   West  13693083.0
# 2  North  13974387.0
# 3   East  14132975.0

# %%
#sales by team
pd.read_sql(
    """
    SELECT Team, SUM(SalesAmount) AS TotalSales
    FROM Sales
    GROUP BY Team
    """,
    engine
)
# Out:
#      Team  TotalSales
# 0  Team A  13840400.0
# 1  Team C  14012249.0
# 2  Team D  14055226.0
# 3  Team B  14494408.0

# %%
#highest sale per category
pd.read_sql(
    """
    SELECT Category, MAX(SalesAmount) AS Highestsale
    FROM Sales
    GROUP BY Category
    """,
    engine
)
# Out:
#       Category  Highestsale
# 0  Electronics        20000
# 1  Accessories        19970

# %%
#lowest profit per region
pd.read_sql(
    """
    SELECT Region, MIN(Profit) AS Minprofit
    FROM Sales
    GROUP BY Region
    """,
    engine
)
# Out:
#   Region  Minprofit
# 0  South       19.8
# 1   West       15.9
# 2  North       20.1
# 3   East       18.6

# %%
#highest profit per region
pd.read_sql(
    """
    SELECT Region, MAX(Profit) AS Minprofit
    FROM Sales
    GROUP BY Region
    """,
    engine
)
# Out:
#   Region  Minprofit
# 0  South     5997.0
# 1   West     5961.0
# 2  North     6000.0
# 3   East     5988.0

# %%
#MONTHLY SALES
#highest profit per region
pd.read_sql(
    """
    SELECT Month, MAX(Profit) AS Minprofit
    FROM Sales
    GROUP BY Region
    """,
    engine
)

# %%
#year wise sale
pd.read_sql(
    """
    SELECT year, MAX(Profit) AS Minprofit
    FROM Sales
    GROUP BY Region
    """,
    engine
)

# %%
#orders count per segment
#year wise sale
pd.read_sql(
    """
    SELECT Segment, COUNT(*) 
    FROM Sales
    GROUP BY Segment
    """,
    engine
)
# Out:
#      Segment  COUNT(*)
# 0  Corporate      2449
# 1  Wholesale      2489
# 2     Retail      2527
# 3     Online      2535

# %%
#average profit per product
pd.read_sql(
    """
    SELECT Product, AVG(Profit) AS Avgprofit
    FROM Sales
    GROUP BY Product
    """,
    engine
)
# Out:
#       Product    Avgprofit
# 0  Smartphone  1686.317009
# 1       Mouse  1691.343925
# 2      Laptop  1709.430806
# 3    Keyboard  1628.768615
# 4      Tablet  1684.864898
# 5     Monitor  1778.484746
# 6      Webcam  1692.914257
# 7     Printer  1718.691583
# 8  Headphones  1642.709548
# 9     Speaker  1678.603046

# %%
#top 3 product by total sale

pd.read_sql(
    """
    SELECT Product, SUM(SalesAmount) AS TotalSales
    FROM Sales
    GROUP BY Product
    ORDER BY TotalSales
    """,
    engine
)
# Out:
#       Product  TotalSales
# 0    Keyboard   5293498.0
# 1     Speaker   5326767.0
# 2       Mouse   5429214.0
# 3  Headphones   5448320.0
# 4      Tablet   5503892.0
# 5      Webcam   5699478.0
# 6     Printer   5717514.0
# 7  Smartphone   5750341.0
# 8      Laptop   5937423.0
# 9     Monitor   6295836.0

# %%
#customer with total purchase >10000
#top 3 product by total sale

pd.read_sql(
    """
    SELECT CustomerName, SUM(SalesAmount) AS TotalSpent
    FROM Sales
    GROUP BY CustomerName
    HAVING SUM(SalesAmount) >10000
    """,
    engine
)
# Out:
#      CustomerName  TotalSpent
# 0    Customer 177    154605.0
# 1    Customer 236     78288.0
# 2    Customer 400    128261.0
# 3    Customer 321    116783.0
# 4    Customer 196     89674.0
# ..            ...         ...
# 495  Customer 331     83597.0
# 496  Customer 232     63146.0
# 497   Customer 81     34077.0
# 498  Customer 216     53562.0
# 499  Customer 266     37993.0
#
# [500 rows x 2 columns]

# %%
#order from corpoarte segment
pd.read_sql(
    """
    SELECT *from Sales WHERE segment='Corporate'
    """,
    engine
)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1     ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 2     ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3     ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
# 4     ORD00023 2023-07-28  Customer 410    Keyboard  Accessories         3
# ...        ...        ...           ...         ...          ...       ...
# 2444  ORD09980 2023-03-26  Customer 211       Mouse  Accessories         1
# 2445  ORD09981 2023-05-14   Customer 66    Keyboard  Accessories         6
# 2446  ORD09984 2023-12-16  Customer 494      Laptop  Electronics         1
# 2447  ORD09993 2023-07-09  Customer 164      Laptop  Electronics         5
# 2448  ORD09999 2023-06-25  Customer 257      Laptop  Electronics         6
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#order from corpoarte segment
pd.read_sql(
    """
    SELECT *from Sales WHERE segment='WholeSale'
    """,
    engine
)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 1     ORD00006 2023-03-19  Customer 123  Smartphone  Electronics         6
# 2     ORD00007 2023-08-29  Customer 169      Tablet  Electronics         6
# 3     ORD00019 2024-01-30  Customer 154      Tablet  Electronics         9
# 4     ORD00020 2024-01-17  Customer 209       Mouse  Accessories        10
# ...        ...        ...           ...         ...          ...       ...
# 2484  ORD09979 2023-11-19  Customer 146  Headphones  Accessories         2
# 2485  ORD09986 2023-09-03  Customer 295       Mouse  Accessories         9
# 2486  ORD09994 2023-03-13  Customer 425  Headphones  Accessories         6
# 2487  ORD09997 2023-12-03  Customer 221     Speaker  Accessories         5
# 2488  ORD10000 2023-08-21  Customer 500  Headphones  Accessories         4
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#order from corpoarte segment
pd.read_sql(
    """
    SELECT *from Sales WHERE Region IN('North','west')
    """,
    engine
)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 1     ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 2     ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
# 3     ORD00006 2023-03-19  Customer 123  Smartphone  Electronics         6
# 4     ORD00007 2023-08-29  Customer 169      Tablet  Electronics         6
# ...        ...        ...           ...         ...          ...       ...
# 4935  ORD09991 2024-01-17  Customer 160  Headphones  Accessories         2
# 4936  ORD09992 2023-09-04  Customer 387     Speaker  Accessories         1
# 4937  ORD09995 2023-12-30   Customer 80      Tablet  Electronics         4
# 4938  ORD09997 2023-12-03  Customer 221     Speaker  Accessories         5
# 4939  ORD09999 2023-06-25  Customer 257      Laptop  Electronics         6
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#sales between 2000 & 5000

pd.read_sql(
    """
    SELECT *from Sales WHERE SalesAmount BETWEEN 2000 AND 5000
    """,
    engine
)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 1     ORD00006 2023-03-19  Customer 123  Smartphone  Electronics         6
# 2     ORD00008 2024-01-06  Customer 283     Monitor  Electronics         5
# 3     ORD00014 2024-01-16  Customer 112      Tablet  Electronics        10
# 4     ORD00027 2023-11-17  Customer 203    Keyboard  Accessories         4
# ...        ...        ...           ...         ...          ...       ...
# 2704  ORD09991 2024-01-17  Customer 160  Headphones  Accessories         2
# 2705  ORD09993 2023-07-09  Customer 164      Laptop  Electronics         5
# 2706  ORD09997 2023-12-03  Customer 221     Speaker  Accessories         5
# 2707  ORD09998 2024-01-28  Customer 114      Laptop  Electronics         5
# 2708  ORD09999 2023-06-25  Customer 257      Laptop  Electronics         6
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#rank orders by salesamount
pd.read_sql("""SELECT OrderID, SalesAmount, RANK() OVER (ORDER BY SalesAmount DESC) AS
SalesRank
FROM Sales""",engine)
# Out:
#        OrderID  SalesAmount  SalesRank
# 0     ORD07051        20000          1
# 1     ORD04924        19990          2
# 2     ORD01446        19970          3
# 3     ORD03890        19960          4
# 4     ORD06002        19960          4
# ...        ...          ...        ...
# 9995  ORD00408           66       9996
# 9996  ORD09992           64       9997
# 9997  ORD05955           63       9998
# 9998  ORD01545           62       9999
# 9999  ORD00897           53      10000
#
# [10000 rows x 3 columns]

# %%
#rank sales within each region 
#rank orders by salesamount
pd.read_sql("""SELECT Region, SalesAmount, RANK() OVER (PARTITION BY Region 
ORDER BY SalesAmount DESC) 
FROM Sales""",engine)
# Out:
#      Region  SalesAmount  \
# 0      East        19960
# 1      East        19960
# 2      East        19910
# 3      East        19830
# 4      East        19720
# ...     ...          ...
# 9995   West           73
# 9996   West           69
# 9997   West           64
# 9998   West           63
# 9999   West           53
#
#       RANK() OVER (PARTITION BY Region \nORDER BY SalesAmount DESC)
# 0                                                     1
# 1                                                     1
# 2                                                     3
# 3                                                     4
# 4                                                     5
# ...                                                 ...
# 9995                                               2436
# 9996                                               2438
# 9997                                               2439
# 9998                                               2440
# ...

# %%
#find duplicate customers
pd.read_sql("""SELECT CustomerName, COUNT(*) from Sales
GROUP BY CustomerName
HAVING Count(*) >1""",engine)
# Out:
#      CustomerName  COUNT(*)
# 0    Customer 177        25
# 1    Customer 236        19
# 2    Customer 400        21
# 3    Customer 321        16
# 4    Customer 196        20
# ..            ...       ...
# 495  Customer 331        20
# 496  Customer 232        11
# 497   Customer 81        13
# 498  Customer 216         7
# 499  Customer 266         7
#
# [500 rows x 2 columns]

# %%
#second highest salesamount
pd.read_sql(""" SELECT MAX(SalesAmount) AS Secondhighestsales
from Sales
WHERE SalesAmount <(SELECT 
MAX(SalesAmount) from Sales)""",engine
)
# Out:
#    Secondhighestsales
# 0               19990

# %%
#orders above average sales
pd.read_sql(""" SELECT *from Sales WHERE SalesAmount > (SELECT AVG(SalesAmount) FROM Sales)""", engine )
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00007 2023-08-29  Customer 169      Tablet  Electronics         6
# 1     ORD00009 2023-08-26  Customer 276      Webcam  Accessories         7
# 2     ORD00010 2023-08-29  Customer 459      Tablet  Electronics         9
# 3     ORD00012 2023-12-16  Customer 398  Smartphone  Electronics         8
# 4     ORD00015 2024-01-13  Customer 209      Laptop  Electronics         5
# ...        ...        ...           ...         ...          ...       ...
# 4104  ORD09986 2023-09-03  Customer 295       Mouse  Accessories         9
# 4105  ORD09987 2023-08-06  Customer 450  Headphones  Accessories         8
# 4106  ORD09994 2023-03-13  Customer 425  Headphones  Accessories         6
# 4107  ORD09995 2023-12-30   Customer 80      Tablet  Electronics         4
# 4108  ORD09996 2023-12-07  Customer 168  Headphones  Accessories        10
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#most profitable product
pd.read_sql(""" SELECT Product,SUM(Profit ) AS TotalProfit
FROM Sales
GROUP BY Product
ORDER BY Totalprofit """,
           engine)
# Out:
#       Product  TotalProfit
# 0    Keyboard    1588049.4
# 1     Speaker    1598030.1
# 2       Mouse    1628764.2
# 3  Headphones    1634496.0
# 4      Tablet    1651167.6
# 5      Webcam    1709843.4
# 6     Printer    1715254.2
# 7  Smartphone    1725102.3
# 8      Laptop    1781226.9
# 9     Monitor    1888750.8

# %%
#least profitable region
pd.read_sql(""" SELECT Region ,SUM(Profit ) AS TotalProfit
FROM Sales
GROUP BY Region
ORDER BY Totalprofit """,
           engine)
# Out:
#   Region  TotalProfit
# 0   West    4107924.9
# 1  North    4192316.1
# 2   East    4239892.5
# 3  South    4380551.4

# %%
#SALES CONTRIBUTION PERCENTAGE
pd.read_sql(""" SELECT  OrderID,(SalesAmount/(SELECT SUM(SalesAmount)
from Sales))*100 AS Percentage from Sales""", engine
           )
# Out:
#        OrderID  Percentage
# 0     ORD00001      0.0026
# 1     ORD00002      0.0048
# 2     ORD00003      0.0021
# 3     ORD00004      0.0099
# 4     ORD00005      0.0023
# ...        ...         ...
# 9995  ORD09996      0.0230
# 9996  ORD09997      0.0050
# 9997  ORD09998      0.0046
# 9998  ORD09999      0.0074
# 9999  ORD10000      0.0035
#
# [10000 rows x 2 columns]

# %%
##44order with zero profit
pd.read_sql(""" SELECT *FROM Sales WHERE Profit =1""",engine)
# Out:
# Empty DataFrame
# Columns: [OrderID, OrderDate, CustomerName, Product, Category, Quantity, SalesAmount, CostPrice, Profit, Region, Segment, Team, SalesExecutive]
# Index: []

# %%
#orders handle by team A
pd.read_sql(""" SELECT *FROM Sales WHERE Team='Team A'""",engine)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1     ORD00008 2024-01-06  Customer 283     Monitor  Electronics         5
# 2     ORD00009 2023-08-26  Customer 276      Webcam  Accessories         7
# 3     ORD00013 2023-07-05  Customer 421     Printer  Accessories         1
# 4     ORD00014 2024-01-16  Customer 112      Tablet  Electronics        10
# ...        ...        ...           ...         ...          ...       ...
# 2478  ORD09968 2023-08-02  Customer 104      Tablet  Electronics         6
# 2479  ORD09974 2023-07-16  Customer 271      Tablet  Electronics         2
# 2480  ORD09979 2023-11-19  Customer 146  Headphones  Accessories         2
# 2481  ORD09988 2023-03-24  Customer 124     Printer  Accessories         5
# 2482  ORD09990 2023-03-18   Customer 22      Tablet  Electronics         4
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#top salesexecutive by sales
pd.read_sql("""  SELECT SalesExecutive ,SUM(SalesAmount) AS TotalSales
from Sales
GROUP BY SalesExecutive
ORDER BY TotalSales DESC """,engine
           )
# Out:
#         SalesExecutive  TotalSales
# 0   Sales Executive 32   1306222.0
# 1   Sales Executive 15   1305441.0
# 2   Sales Executive 42   1275641.0
# 3   Sales Executive 16   1272955.0
# 4   Sales Executive 46   1245480.0
# 5    Sales Executive 5   1234474.0
# 6   Sales Executive 24   1234029.0
# 7    Sales Executive 2   1221854.0
# 8   Sales Executive 20   1220982.0
# 9   Sales Executive 34   1218185.0
# 10   Sales Executive 4   1211117.0
# 11  Sales Executive 33   1202863.0
# 12  Sales Executive 10   1195144.0
# 13  Sales Executive 36   1193892.0
# 14  Sales Executive 25   1175802.0
# 15  Sales Executive 21   1168264.0
# 16   Sales Executive 6   1167909.0
# 17  Sales Executive 12   1162983.0
# 18  Sales Executive 35   1158626.0
# 19  Sales Executive 23   1158182.0
# 20  Sales Executive 14   1153306.0
# 21  Sales Executive 31   1138390.0
# 22  Sales Executive 37   1136393.0
# 23  Sales Executive 41   1134890.0
# 24  Sales Executive 38   1128135.0
# 25  Sales Executive 45   1126178.0
# ...

# %%
#DATE WISE SALES
pd.read_sql(""" SELECT OrderDate, SUM(SalesAmount)
from Sales
GROUP BY OrderDate""",engine )
# Out:
#      OrderDate  SUM(SalesAmount)
# 0   2024-01-06          187012.0
# 1   2023-10-25          225954.0
# 2   2023-04-10          118770.0
# 3   2023-09-12          119156.0
# 4   2023-03-08          130805.0
# ..         ...               ...
# 361 2024-02-02          195393.0
# 362 2024-02-01           98014.0
# 363 2023-12-05          105828.0
# 364 2023-04-08          146538.0
# 365 2024-02-04           84331.0
#
# [366 rows x 2 columns]

# %%
#backup sales table
#pd.read_sql(""" CREATE TABLE Sale_backup AS from SELECT*from Sales""",engine)

# %%
#1display all recoreds from  sales table
pd.read_sql(""" SELECT * FROM Sales""",engine)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1     ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 2     ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3     ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 4     ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
# ...        ...        ...           ...         ...          ...       ...
# 9995  ORD09996 2023-12-07  Customer 168  Headphones  Accessories        10
# 9996  ORD09997 2023-12-03  Customer 221     Speaker  Accessories         5
# 9997  ORD09998 2024-01-28  Customer 114      Laptop  Electronics         5
# 9998  ORD09999 2023-06-25  Customer 257      Laptop  Electronics         6
# 9999  ORD10000 2023-08-21  Customer 500  Headphones  Accessories         4
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#2display only customername and salesamount
pd.read_sql(""" SELECT CustomerName,SalesAmount FROM Sales """,engine)
# Out:
#       CustomerName  SalesAmount
# 0     Customer 177         1443
# 1     Customer 236         2718
# 2     Customer 400         1212
# 3     Customer 321         5601
# 4     Customer 196         1310
# ...            ...          ...
# 9995  Customer 168        12980
# 9996  Customer 221         2820
# 9997  Customer 114         2585
# 9998  Customer 257         4170
# 9999  Customer 500         1968
#
# [10000 rows x 2 columns]

# %%
#3find unique product name
pd.read_sql(""" SELECT DISTINCT Product from Sales""",engine)
# Out:
#       Product
# 0  Smartphone
# 1       Mouse
# 2      Laptop
# 3    Keyboard
# 4      Tablet
# 5     Monitor
# 6      Webcam
# 7     Printer
# 8  Headphones
# 9     Speaker

# %%
#4#show sales where salesamount>5000
pd.read_sql(""" SELECT * FROM Sales WHERE SalesAmount >5000""",engine)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 1     ORD00007 2023-08-29  Customer 169      Tablet  Electronics         6
# 2     ORD00009 2023-08-26  Customer 276      Webcam  Accessories         7
# 3     ORD00010 2023-08-29  Customer 459      Tablet  Electronics         9
# 4     ORD00012 2023-12-16  Customer 398  Smartphone  Electronics         8
# ...        ...        ...           ...         ...          ...       ...
# 4581  ORD09986 2023-09-03  Customer 295       Mouse  Accessories         9
# 4582  ORD09987 2023-08-06  Customer 450  Headphones  Accessories         8
# 4583  ORD09994 2023-03-13  Customer 425  Headphones  Accessories         6
# 4584  ORD09995 2023-12-30   Customer 80      Tablet  Electronics         4
# 4585  ORD09996 2023-12-07  Customer 168  Headphones  Accessories        10
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#5find sales from the electronic category
pd.read_sql(""" SELECT Category from Sales WHERE Category='Electronics'""",engine)
# Out:
#          Category
# 0     Electronics
# 1     Electronics
# 2     Electronics
# 3     Electronics
# 4     Electronics
# ...           ...
# 4102  Electronics
# 4103  Electronics
# 4104  Electronics
# 4105  Electronics
# 4106  Electronics
#
# [4107 rows x 1 columns]

# %%
#6sort sales by salesamount in descending order
pd.read_sql(""" SELECT * FROM Sales ORDER BY SalesAmount DESC""",engine)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD07051 2023-05-12  Customer 221     Monitor  Electronics        10
# 1     ORD04924 2023-09-22  Customer 258  Smartphone  Electronics        10
# 2     ORD01446 2023-11-19  Customer 297  Headphones  Accessories        10
# 3     ORD06002 2024-01-22  Customer 400      Laptop  Electronics        10
# 4     ORD03890 2023-05-07  Customer 187       Mouse  Accessories        10
# ...        ...        ...           ...         ...          ...       ...
# 9995  ORD00408 2023-07-25  Customer 395  Smartphone  Electronics         1
# 9996  ORD09992 2023-09-04  Customer 387     Speaker  Accessories         1
# 9997  ORD05955 2023-09-11   Customer 78  Headphones  Accessories         1
# 9998  ORD01545 2023-04-24  Customer 495     Monitor  Electronics         1
# 9999  ORD00897 2023-05-13   Customer 43  Smartphone  Electronics         1
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#7 display top 5 highest sales
pd.read_sql(""" SELECT *FROM Sales ORDER BY SalesAmount DESC LIMIT 5""",engine)
# Out:
#     OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0  ORD07051 2023-05-12  Customer 221     Monitor  Electronics        10
# 1  ORD04924 2023-09-22  Customer 258  Smartphone  Electronics        10
# 2  ORD01446 2023-11-19  Customer 297  Headphones  Accessories        10
# 3  ORD06002 2024-01-22  Customer 400      Laptop  Electronics        10
# 4  ORD03890 2023-05-07  Customer 187       Mouse  Accessories        10
#
#    SalesAmount  CostPrice  Profit Region    Segment    Team  \
# 0        20000     1400.0  6000.0  North     Retail  Team A
# 1        19990     1399.3  5997.0  South  Wholesale  Team A
# 2        19970     1397.9  5991.0  North     Online  Team C
# 3        19960     1397.2  5988.0   East  Corporate  Team D
# 4        19960     1397.2  5988.0   East     Online  Team B
#
#        SalesExecutive
# 0   Sales Executive 1
# 1  Sales Executive 24
# 2   Sales Executive 5
# 3  Sales Executive 25
# 4  Sales Executive 45

# %%
#7 display top 5 highest sales
pd.read_sql(""" SELECT *FROM Sales ORDER BY SalesAmount ASC LIMIT 5""",engine)
# Out:
#     OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0  ORD00897 2023-05-13   Customer 43  Smartphone  Electronics         1
# 1  ORD01545 2023-04-24  Customer 495     Monitor  Electronics         1
# 2  ORD05955 2023-09-11   Customer 78  Headphones  Accessories         1
# 3  ORD09992 2023-09-04  Customer 387     Speaker  Accessories         1
# 4  ORD00408 2023-07-25  Customer 395  Smartphone  Electronics         1
#
#    SalesAmount  CostPrice  Profit Region    Segment    Team  \
# 0           53       37.1    15.9   West  Wholesale  Team A
# 1           62       43.4    18.6   East  Corporate  Team C
# 2           63       44.1    18.9   West     Online  Team C
# 3           64       44.8    19.2   West     Retail  Team D
# 4           66       46.2    19.8  South     Retail  Team B
#
#        SalesExecutive
# 0   Sales Executive 7
# 1  Sales Executive 27
# 2  Sales Executive 40
# 3  Sales Executive 28
# 4  Sales Executive 24

# %%
#8count total number of sales records
pd.read_sql(""" SELECT COUNT(*)  FROM Sales""",engine)
# Out:
#    COUNT(*)
# 0     10000

# %%
#9find minimum sales amount
pd.read_sql(""" SELECT MIN(SalesAmount) from Sales""",engine)
# Out:
#    MIN(SalesAmount)
# 0                53

# %%
#10find maxmum sales amount

pd.read_sql(""" SELECT MAX(SalesAmount) from Sales""",engine)
# Out:
#    MAX(SalesAmount)
# 0             20000

# %%
#10a)find AVG sales amount

pd.read_sql(""" SELECT AVG(SalesAmount) from Sales""",engine)
# Out:
#    AVG(SalesAmount)
# 0         5640.2283

# %%
#AGGREGATE & GROUP BY 11 FIND TOTAL SALESAMOUNT
pd.read_sql(""" SELECT SUM(SalesAmount ) from Sales""",engine)
# Out:
#    SUM(SalesAmount )
# 0         56402283.0

# %%
#12 find average sales amount
pd.read_sql(""" SELECT AVG(SalesAmount) from Sales""",engine)
# Out:
#    AVG(SalesAmount)
# 0         5640.2283

# %%
#13total sales per category
pd.read_sql(""" SELECT Category, SUM(SalesAmount)
from Sales
GROUP BY Category""",engine )
# Out:
#       Category  SUM(SalesAmount)
# 0  Electronics        23487492.0
# 1  Accessories        32914791.0

# %%
#14 total sales per region
pd.read_sql(""" SELECT Region , SUM(SalesAmount) from Sales
GROUP BY Region""",engine)
# Out:
#   Region  SUM(SalesAmount)
# 0  South        14601838.0
# 1   West        13693083.0
# 2  North        13974387.0
# 3   East        14132975.0

# %%
pd.read_sql(""" SELECT Region ,MAX(SalesAmount)  AS maxsales
from Sales
GROUP BY Region  
ORDER BY maxsales DESC """,engine)
# Out:
#   Region  maxsales
# 0  North     20000
# 1  South     19990
# 2   East     19960
# 3   West     19870

# %%
#15 count number of sales per product
pd.read_sql(""" SELECT Product, COUNT(*) FROM Sales
GROUP BY Product""",engine)
# Out:
#       Product  COUNT(*)
# 0  Smartphone      1023
# 1       Mouse       963
# 2      Laptop      1042
# 3    Keyboard       975
# 4      Tablet       980
# 5     Monitor      1062
# 6      Webcam      1010
# 7     Printer       998
# 8  Headphones       995
# 9     Speaker       952

# %%
#16categories with total sales>50,000
pd.read_sql(""" SELECT Category ,SUM(SalesAmount)
from Sales
GROUP BY Category
HAVING SUM(SalesAmount)""",engine)
# Out:
#       Category  SUM(SalesAmount)
# 0  Electronics        23487492.0
# 1  Accessories        32914791.0

# %%
#17 REGION WITH MORE THAN 10 SALES
pd.read_sql(""" SELECT Region ,MIN(SalesAmount)
from Sales
GROUP BY Region
ORDER BY MAX(SalesAmount) DESC LIMIT 10""",engine)
# Out:
#   Region  MIN(SalesAmount)
# 0  North                67
# 1  South                66
# 2   East                62
# 3   West                53

# %%
#18AVERAGE SALES PER CATEGORY
pd.read_sql(""" SELECT Category ,AVG(SalesAmount) from Sales
GROUP BY Category
HAVING AVG(SalesAmount)""",engine)
# Out:
#       Category  AVG(SalesAmount)
# 0  Electronics         5718.8926
# 1  Accessories         5585.4049

# %%
#19highest sales in each region
pd.read_sql(""" SELECT Region ,MAX(SalesAmount) from Sales
GROUP BY Region 
ORDER BY MAX(SalesAmount) DESC""",engine)
# Out:
#   Region  MAX(SalesAmount)
# 0  North             20000
# 1  South             19990
# 2   East             19960
# 3   West             19870

# %%
#20 TOTAL QUANTITY SOLD PER PRODUCT
pd.read_sql(""" SELECT Product,SUM(Quantity) from Sales
GROUP BY Product
ORDER BY  SUM(Quantity) DESC """,engine)
# Out:
#       Product  SUM(Quantity)
# 0     Monitor         5868.0
# 1      Laptop         5837.0
# 2  Smartphone         5677.0
# 3     Printer         5515.0
# 4      Tablet         5451.0
# 5      Webcam         5442.0
# 6  Headphones         5389.0
# 7    Keyboard         5306.0
# 8       Mouse         5281.0
# 9     Speaker         5270.0

# %%
#JOINS 21 INNER JOIN SALES+CUSTOMER
#pd.read_sql(""" SELECT S.*,C.CustomerName
 #          from Sales
  #         INNER JOIN Customers C
   #        ON S.CustomerName = C.CUstomerName""",engine) 
#the excel file only one table there is no another table so we cant joins the table

# %%
#subquery sales greater than avg sales
pd.read_sql(""" SELECT *  FROM Sales
WHERE SalesAmount > (SELECT AVG(SalesAmount)from Sales 
ORDER BY  SalesAmount ASC )""",engine)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00007 2023-08-29  Customer 169      Tablet  Electronics         6
# 1     ORD00009 2023-08-26  Customer 276      Webcam  Accessories         7
# 2     ORD00010 2023-08-29  Customer 459      Tablet  Electronics         9
# 3     ORD00012 2023-12-16  Customer 398  Smartphone  Electronics         8
# 4     ORD00015 2024-01-13  Customer 209      Laptop  Electronics         5
# ...        ...        ...           ...         ...          ...       ...
# 4104  ORD09986 2023-09-03  Customer 295       Mouse  Accessories         9
# 4105  ORD09987 2023-08-06  Customer 450  Headphones  Accessories         8
# 4106  ORD09994 2023-03-13  Customer 425  Headphones  Accessories         6
# 4107  ORD09995 2023-12-30   Customer 80      Tablet  Electronics         4
# 4108  ORD09996 2023-12-07  Customer 168  Headphones  Accessories        10
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#customer who made more than one purchase
pd.read_sql(""" SELECT CustomerName from Sales
GROUP BY CustomerName
HAVING COUNT(*)>1""",engine)
# Out:
#      CustomerName
# 0    Customer 177
# 1    Customer 236
# 2    Customer 400
# 3    Customer 321
# 4    Customer 196
# ..            ...
# 495  Customer 331
# 496  Customer 232
# 497   Customer 81
# 498  Customer 216
# 499  Customer 266
#
# [500 rows x 1 columns]

# %%
#SECOND HIGHEST SALES AMOUNT
pd.read_sql(""" SELECT SalesAmount
from Sales
WHERE SalesAmount<(SELECT MAX(SalesAmount) from Sales
ORDER BY SalesAmount DESC )""",engine)
# Out:
#       SalesAmount
# 0            1443
# 1            2718
# 2            1212
# 3            5601
# 4            1310
# ...           ...
# 9994        12980
# 9995         2820
# 9996         2585
# 9997         4170
# 9998         1968
#
# [9999 rows x 1 columns]

# %%
#sales from top selling category
pd.read_sql(""" SELECT *  from Sales
WHERE Category=(
SELECT Category from Sales
GROUP BY Category 
ORDER BY SUM(SalesAmount) DESC LIMIT 1)""",engine)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 1     ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 2     ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
# 3     ORD00009 2023-08-26  Customer 276      Webcam  Accessories         7
# 4     ORD00013 2023-07-05  Customer 421     Printer  Accessories         1
# ...        ...        ...           ...         ...          ...       ...
# 5888  ORD09992 2023-09-04  Customer 387     Speaker  Accessories         1
# 5889  ORD09994 2023-03-13  Customer 425  Headphones  Accessories         6
# 5890  ORD09996 2023-12-07  Customer 168  Headphones  Accessories        10
# 5891  ORD09997 2023-12-03  Customer 221     Speaker  Accessories         5
# 5892  ORD10000 2023-08-21  Customer 500  Headphones  Accessories         4
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#FUNCTION & CASE 31CONVERT PRODUCT NAMES TO UPPERCASE
pd.read_sql(""" SELECT UPPER(Product) from Sales""",engine)
# Out:
#      UPPER(Product)
# 0        SMARTPHONE
# 1             MOUSE
# 2            LAPTOP
# 3          KEYBOARD
# 4          KEYBOARD
# ...             ...
# 9995     HEADPHONES
# 9996        SPEAKER
# 9997         LAPTOP
# 9998         LAPTOP
# 9999     HEADPHONES
#
# [10000 rows x 1 columns]

# %%
#extract year from Salesdate
pd.read_sql(""" SELECT YEAR(OrderDate) from Sales""",engine)
# Out:
#       YEAR(OrderDate)
# 0                2024
# 1                2023
# 2                2023
# 3                2023
# 4                2023
# ...               ...
# 9995             2023
# 9996             2023
# 9997             2024
# 9998             2023
# 9999             2023
#
# [10000 rows x 1 columns]

# %%
#shoe month wise sales
#extract year from Salesdate
pd.read_sql(""" SELECT MONTH(OrderDate),SUM(SalesAmount) from Sales
GROUP BY MONTH(OrderDate) """,engine)
# Out:
#     MONTH(OrderDate)  SUM(SalesAmount)
# 0                  1         4882727.0
# 1                 10         4621391.0
# 2                  4         4347436.0
# 3                  9         4608661.0
# 4                  3         4889380.0
# 5                  8         4993202.0
# 6                 12         4793406.0
# 7                  7         4882027.0
# 8                  5         4799520.0
# 9                  2         4379033.0
# 10                 6         4836347.0
# 11                11         4369153.0

# %%
#replace null regi on with unknown
pd.read_sql(""" SELECT IFNULL(Region,'unknown') from Sales""",engine)
# Out:
#      IFNULL(Region,'unknown')
# 0                       South
# 1                        West
# 2                       South
# 3                       North
# 4                        West
# ...                       ...
# 9995                     East
# 9996                     West
# 9997                     East
# 9998                     West
# 9999                    South
#
# [10000 rows x 1 columns]

# %%
#categorize sales using case
pd.read_sql(""" SELECT SalesAmount,
CASE
WHEN SalesAmount >10000 then 'high'
WHEN SalesAmount BETWEEN 5000 AND 10000 then 'medium'
ELSE 'LOW'
END AS SalesAmount
from Sales""",engine)
# Out:
#      SalesAmount SalesAmount
# 0           1443         LOW
# 1           2718         LOW
# 2           1212         LOW
# 3           5601      medium
# 4           1310         LOW
# ...          ...         ...
# 9995       12980        high
# 9996        2820         LOW
# 9997        2585         LOW
# 9998        4170         LOW
# 9999        1968         LOW
#
# [10000 rows x 2 columns]

# %%
#lenght of product name
pd.read_sql(""" SELECT product,  LENGTH(Product) from Sales""",engine)
# Out:
#          product  LENGTH(Product)
# 0     Smartphone               10
# 1          Mouse                5
# 2         Laptop                6
# 3       Keyboard                8
# 4       Keyboard                8
# ...          ...              ...
# 9995  Headphones               10
# 9996     Speaker                7
# 9997      Laptop                6
# 9998      Laptop                6
# 9999  Headphones               10
#
# [10000 rows x 2 columns]

# %%
#concatenate customername and region
pd.read_sql(""" SELECT  CONCAT(CustomerName,'---',Region)  as Regionwise from Sales""",engine)
# Out:
#                 Regionwise
# 0     Customer 177---South
# 1      Customer 236---West
# 2     Customer 400---South
# 3     Customer 321---North
# 4      Customer 196---West
# ...                    ...
# 9995   Customer 168---East
# 9996   Customer 221---West
# 9997   Customer 114---East
# 9998   Customer 257---West
# 9999  Customer 500---South
#
# [10000 rows x 1 columns]

# %%
#find sales made today
pd.read_sql(""" SELECT * from Sales
WHERE OrderDate = CURRENT_DATE""",engine)
# Out:
# Empty DataFrame
# Columns: [OrderID, OrderDate, CustomerName, Product, Category, Quantity, SalesAmount, CostPrice, Profit, Region, Segment, Team, SalesExecutive]
# Index: []

# %%
#TOTAL SALES IN LAST 30 DAYS
pd.read_sql(""" SELECT SUM(SalesAmount) from Sales 
WHERE SalesAmount>=CURRENT_DATE-INTERVAL 30 DAY""",engine)
# Out:
#   SUM(SalesAmount)
# 0             None

# %%
#round sales amoount to 2 decimal
pd.read_sql(""" SELECT ROUND(SalesAmount,2) FROM Sales""",engine)
# Out:
#       ROUND(SalesAmount,2)
# 0                     1443
# 1                     2718
# 2                     1212
# 3                     5601
# 4                     1310
# ...                    ...
# 9995                 12980
# 9996                  2820
# 9997                  2585
# 9998                  4170
# 9999                  1968
#
# [10000 rows x 1 columns]

# %%
import pandas as pd
df= pd.read_excel("College_Students_SQL_Project_Ready.xlsx")
df.head()
# Out:
#    Student_ID Student_Name  Gender Department  Graduation_Year  \
# 0           1        Anand    Male        CSE             2023
# 1           2       Harini  Female        CSE             2023
# 2           3        Rohit    Male        CSE             2023
# 3           4      Shruthi  Female         IT             2023
# 4           5       Harish    Male        CSE             2023
#
#                 Current_Status  Internship Duration (Months)  Project  \
# 0              Editing Working                             6        3
# 1  Government Exam Preparation                             5        1
# 2                     Business                             3        2
# 3            Marketing Working                             2        2
# 4           IT Company Working                             4        3
#
#   Location               Email        Area of Interest  CGPA
# 0    India    anand1@gmail.com         Web Development  7.16
# ...

# %%
import pandas as pd
pd.read_sql("SHOW TABLES",engine)
# Out:
#         Tables_in_ri
# 0        application
# 1   college_students
# 2          companies
# 3          highsales
# 4         interviews
# 5                lcu
# 6               loke
# 7               loki
# 8              sales
# 9           students
# 10         students2

# %%
pd.read_sql("SELECT * FROM College_Students",engine)
# Out:
#      Student_ID Student_Name  Gender Department  Graduation_Year  \
# 0             1        Anand    Male        CSE             2023
# 1             2       Harini  Female        CSE             2023
# 2             3        Rohit    Male        CSE             2023
# 3             4      Shruthi  Female         IT             2023
# 4             5       Harish    Male        CSE             2023
# ..          ...          ...     ...        ...              ...
# 495         496       Harini  Female        CSE             2023
# 496         497         Ravi    Male    AI & DS             2023
# 497         498      Lakshmi  Female         IT             2023
# 498         499        Vijay    Male    AI & DS             2023
# 499         500     Pavithra  Female    AI & DS             2023
#
#                   Current_Status  Internship Duration (Months)  Project  \
# 0                Editing Working                             6        3
# ...

# %%
pd.read_sql(""" SELECT  * from College_Students """,engine )
# Out:
#      Student_ID Student_Name  Gender Department  Graduation_Year  \
# 0             1        Anand    Male        CSE             2023
# 1             2       Harini  Female        CSE             2023
# 2             3        Rohit    Male        CSE             2023
# 3             4      Shruthi  Female         IT             2023
# 4             5       Harish    Male        CSE             2023
# ..          ...          ...     ...        ...              ...
# 495         496       Harini  Female        CSE             2023
# 496         497         Ravi    Male    AI & DS             2023
# 497         498      Lakshmi  Female         IT             2023
# 498         499        Vijay    Male    AI & DS             2023
# 499         500     Pavithra  Female    AI & DS             2023
#
#                   Current_Status  Internship Duration (Months)  Project  \
# 0                Editing Working                             6        3
# ...

# %%
pd.read_sql(""" SELECT Student_Name, Department from College_Students""",engine)
# Out:
#     Student_Name Department
# 0          Anand        CSE
# 1         Harini        CSE
# 2          Rohit        CSE
# 3        Shruthi         IT
# 4         Harish        CSE
# ..           ...        ...
# 495       Harini        CSE
# 496         Ravi    AI & DS
# 497      Lakshmi         IT
# 498        Vijay    AI & DS
# 499     Pavithra    AI & DS
#
# [500 rows x 2 columns]

# %%
pd.read_sql(""" SELECT *  from College_Students  where Department ='CSE' """,engine )
# Out:
#      Student_ID Student_Name  Gender Department  Graduation_Year  \
# 0             1        Anand    Male        CSE             2023
# 1             2       Harini  Female        CSE             2023
# 2             3        Rohit    Male        CSE             2023
# 3             5       Harish    Male        CSE             2023
# 4             9       Harish    Male        CSE             2023
# ..          ...          ...     ...        ...              ...
# 181         489        Manoj    Male        CSE             2023
# 182         490      Keerthi  Female        CSE             2023
# 183         491       Suresh    Male        CSE             2023
# 184         493        Vijay    Male        CSE             2023
# 185         496       Harini  Female        CSE             2023
#
#                   Current_Status  Internship Duration (Months)  Project  \
# 0                Editing Working                             6        3
# ...

# %%
pd.read_sql( """SELECT * from College_Students WHERE Current_Status ='PG' """,engine )
# Out:
# Empty DataFrame
# Columns: [Student_ID, Student_Name, Gender, Department, Graduation_Year, Current_Status, Internship Duration (Months), Project, Location, Email, Area of Interest, CGPA]
# Index: []

# %%
pd.read_sql(""" SELECT *  from College_Students  where Department ='IT' """,engine )
# Out:
#      Student_ID Student_Name  Gender Department  Graduation_Year  \
# 0             4      Shruthi  Female         IT             2023
# 1             8        Sneha  Female         IT             2023
# 2            12    Aishwarya  Female         IT             2023
# 3            13        Rahul    Male         IT             2023
# 4            17        Surya    Male         IT             2023
# ..          ...          ...     ...        ...              ...
# 142         487        Anand    Male         IT             2023
# 143         492        Pooja  Female         IT             2023
# 144         494       Bhavya  Female         IT             2023
# 145         495         Ravi    Male         IT             2023
# 146         498      Lakshmi  Female         IT             2023
#
#         Current_Status  Internship Duration (Months)  Project Location  \
# 0    Marketing Working                             2        2    India
# ...

# %%
pd.read_sql(""" SELECT * FROM College_Students WHERE  Gender='Female'""",engine)
# Out:
#      Student_ID Student_Name  Gender Department  Graduation_Year  \
# 0             2       Harini  Female        CSE             2023
# 1             4      Shruthi  Female         IT             2023
# 2             6      Keerthi  Female    AI & DS             2023
# 3             8        Sneha  Female         IT             2023
# 4            10    Aishwarya  Female        CSE             2023
# ..          ...          ...     ...        ...              ...
# 245         492        Pooja  Female         IT             2023
# 246         494       Bhavya  Female         IT             2023
# 247         496       Harini  Female        CSE             2023
# 248         498      Lakshmi  Female         IT             2023
# 249         500     Pavithra  Female    AI & DS             2023
#
#                   Current_Status  Internship Duration (Months)  Project  \
# 0    Government Exam Preparation                             5        1
# ...

# %%
pd.read_sql(""" select * from College_Students where Current_Status  = 'IT Working'""",engine)
# Out:
# Empty DataFrame
# Columns: [Student_ID, Student_Name, Gender, Department, Graduation_Year, Current_Status, Internship Duration (Months), Project, Location, Email, Area of Interest, CGPA]
# Index: []

# %%
pd.read_sql(""" SELECT *  from College_Students  where Department ='AI & DS' """,engine )
# Out:
#      Student_ID Student_Name  Gender Department  Graduation_Year  \
# 0             6      Keerthi  Female    AI & DS             2023
# 1             7        Surya    Male    AI & DS             2023
# 2            16      Keerthi  Female    AI & DS             2023
# 3            23        Surya    Male    AI & DS             2023
# 4            25      Prakash    Male    AI & DS             2023
# ..          ...          ...     ...        ...              ...
# 162         478      Keerthi  Female    AI & DS             2023
# 163         481       Sanjay    Male    AI & DS             2023
# 164         497         Ravi    Male    AI & DS             2023
# 165         499        Vijay    Male    AI & DS             2023
# 166         500     Pavithra  Female    AI & DS             2023
#
#                   Current_Status  Internship Duration (Months)  Project  \
# 0                  Other Courses                             3        1
# ...

# %%
pd.read_sql(""" select * from College_Students where Current_Status  = 'Government Exam Preparation'""",engine)
# Out:
#     Student_ID Student_Name  Gender Department  Graduation_Year  \
# 0            2       Harini  Female        CSE             2023
# 1            7        Surya    Male    AI & DS             2023
# 2           49        Rohit    Male         IT             2023
# 3           62      Rithika  Female        CSE             2023
# 4           90       Harini  Female         IT             2023
# 5           94       Bhavya  Female        CSE             2023
# 6           99       Suresh    Male         IT             2023
# 7          114    Vaishnavi  Female        CSE             2023
# 8          118    Aishwarya  Female         IT             2023
# 9          121        Rohit    Male        CSE             2023
# 10         141        Rohit    Male    AI & DS             2023
# 11         149        Manoj    Male        CSE             2023
# 12         158    Aishwarya  Female    AI & DS             2023
# 13         164       Bhavya  Female         IT             2023
# ...

# %%
pd.read_sql(""" select * from College_Students where Current_Status  = 'Internships'""",engine)
# Out:
# Empty DataFrame
# Columns: [Student_ID, Student_Name, Gender, Department, Graduation_Year, Current_Status, Internship Duration (Months), Project, Location, Email, Area of Interest, CGPA]
# Index: []

# %%
pd.read_sql(""" select  Email from College_Students""",engine )
# Out:
#                      Email
# 0         anand1@gmail.com
# 1        harini2@gmail.com
# 2         rohit3@gmail.com
# 3       shruthi4@gmail.com
# 4        harish5@gmail.com
# ..                     ...
# 495    harini496@gmail.com
# 496      ravi497@gmail.com
# 497   lakshmi498@gmail.com
# 498     vijay499@gmail.com
# 499  pavithra500@gmail.com
#
# [500 rows x 1 columns]

# %%
pd.read_sql(""" select DISTINCT Department from College_Students""",engine)
# Out:
#   Department
# 0        CSE
# 1         IT
# 2    AI & DS

# %%
pd.read_sql(""" select DISTINCT Current_Status from College_Students""",engine)
# Out:
#                  Current_Status
# 0               Editing Working
# 1   Government Exam Preparation
# 2                      Business
# 3             Marketing Working
# 4            IT Company Working
# 5                 Other Courses
# 6                    HR Working
# 7                    Internship
# 8               Foreign Studies
# 9                    PG Studies
# 10                     Marriage

# %%
pd.read_sql("""select Student_Name from College_students ORDER BY  Student_Name ASC """,engine)
# Out:
#     Student_Name
# 0      Aishwarya
# 1      Aishwarya
# 2      Aishwarya
# 3      Aishwarya
# 4      Aishwarya
# ..           ...
# 495       Vikram
# 496       Vikram
# 497       Vikram
# 498       Vikram
# 499       Vikram
#
# [500 rows x 1 columns]

# %%
pd.read_sql(""" select Department from College_Students
ORDER BY Department
""", engine )
# Out:
#     Department
# 0      AI & DS
# 1      AI & DS
# 2      AI & DS
# 3      AI & DS
# 4      AI & DS
# ..         ...
# 495         IT
# 496         IT
# 497         IT
# 498         IT
# 499         IT
#
# [500 rows x 1 columns]

# %%
pd.read_sql(""" select * from College_students ORDER BY Student_Name ASC
 LIMIT 10   """,engine)
# Out:
#    Student_ID Student_Name  Gender Department  Graduation_Year  \
# 0          10    Aishwarya  Female        CSE             2023
# 1         138    Aishwarya  Female         IT             2023
# 2         454    Aishwarya  Female    AI & DS             2023
# 3         162    Aishwarya  Female         IT             2023
# 4         118    Aishwarya  Female         IT             2023
# 5          12    Aishwarya  Female         IT             2023
# 6         468    Aishwarya  Female        CSE             2023
# 7         270    Aishwarya  Female         IT             2023
# 8          86    Aishwarya  Female         IT             2023
# 9         358    Aishwarya  Female         IT             2023
#
#                 Current_Status  Internship Duration (Months)  Project  \
# 0            Marketing Working                             2        3
# 1           IT Company Working                             6        1
# ...

# %%
pd.read_sql(""" select Current_Status from College_Students 
ORDER BY Current_Status""",engine )
# Out:
#     Current_Status
# 0         Business
# 1         Business
# 2         Business
# 3         Business
# 4         Business
# ..             ...
# 495     PG Studies
# 496     PG Studies
# 497     PG Studies
# 498     PG Studies
# 499     PG Studies
#
# [500 rows x 1 columns]

# %%
pd.read_sql(""" select Current_Status from  College_Students  
where  Current_Status = 'IT'  
ORDER BY Current_Status LIMIT 5 """
            ,engine )
# Out:
# Empty DataFrame
# Columns: [Current_Status]
# Index: []

# %%
pd.read_sql(""" select Student_Name from College_Students
ORDER BY Student_Name DESC """,engine)
# Out:
#     Student_Name
# 0         Vikram
# 1         Vikram
# 2         Vikram
# 3         Vikram
# 4         Vikram
# ..           ...
# 495    Aishwarya
# 496    Aishwarya
# 497    Aishwarya
# 498    Aishwarya
# 499    Aishwarya
#
# [500 rows x 1 columns]

# %%
pd.read_sql(""" select COUNT(*) from College_Students""",engine )
# Out:
#    COUNT(*)
# 0       500

# %%
pd.read_sql(""" select  COUNT(*) from College_Students where Department = 'CSE'""",engine )
# Out:
#    COUNT(*)
# 0       186

# %%
pd.read_sql(" select COUNT(*) from College_Students where Gender= 'male'",engine)
# Out:
#    COUNT(*)
# 0       250

# %%
pd.read_sql("""select Department,COUNT(*) from College_Students 
GROUP BY Department """,engine)
# Out:
#   Department  COUNT(*)
# 0        CSE       186
# 1         IT       147
# 2    AI & DS       167

# %%
pd.read_sql(""" select Current_Status,COUNT(*) 
from College_Students
GROUP BY Current_Status""",engine)
# Out:
#                  Current_Status  COUNT(*)
# 0               Editing Working        45
# 1   Government Exam Preparation        47
# 2                      Business        43
# 3             Marketing Working        56
# 4            IT Company Working        42
# 5                 Other Courses        50
# 6                    HR Working        51
# 7                    Internship        46
# 8               Foreign Studies        42
# 9                    PG Studies        42
# 10                     Marriage        36

# %%
pd.read_sql(""" select MIN(Student_ID) from  College_Students""",engine)
# Out:
#    MIN(Student_ID)
# 0                1

# %%
pd.read_sql(""" select COUNT(*) from College_Students
where Current_Status='Internship'""",engine)
# Out:
#    COUNT(*)
# 0        46

# %%
pd.read_sql(""" select Department, COUNT(*) FROM College_Students
where Gender= 'Female'
GROUP BY Department""",engine)
# Out:
#   Department  COUNT(*)
# 0        CSE        88
# 1         IT        82
# 2    AI & DS        80

# %%
pd.read_sql(""" select Current_Status,COUNT(*) from College_Students
where Current_Status= 'HR Working' """,engine )
# Out:
#   Current_Status  COUNT(*)
# 0     HR Working        51

# %%
pd.read_sql(""" select  * from College_Students 
where Student_Name LIKE 'A%%' """,engine)
# Out:
#     Student_ID Student_Name  Gender Department  Graduation_Year  \
# 0            1        Anand    Male        CSE             2023
# 1           10    Aishwarya  Female        CSE             2023
# 2           12    Aishwarya  Female         IT             2023
# 3           14       Ananya  Female        CSE             2023
# 4           37        Anand    Male    AI & DS             2023
# ..         ...          ...     ...        ...              ...
# 67         468    Aishwarya  Female        CSE             2023
# 68         469         Amit    Male         IT             2023
# 69         476       Ananya  Female         IT             2023
# 70         483        Anand    Male        CSE             2023
# 71         487        Anand    Male         IT             2023
#
#        Current_Status  Internship Duration (Months)  Project Location  \
# 0     Editing Working                             6        3    India
# ...

# %%
pd.read_sql(""" select * from College_Students where Department in('CSE','IT')""",engine)
# Out:
#      Student_ID Student_Name  Gender Department  Graduation_Year  \
# 0             1        Anand    Male        CSE             2023
# 1             2       Harini  Female        CSE             2023
# 2             3        Rohit    Male        CSE             2023
# 3             4      Shruthi  Female         IT             2023
# 4             5       Harish    Male        CSE             2023
# ..          ...          ...     ...        ...              ...
# 328         493        Vijay    Male        CSE             2023
# 329         494       Bhavya  Female         IT             2023
# 330         495         Ravi    Male         IT             2023
# 331         496       Harini  Female        CSE             2023
# 332         498      Lakshmi  Female         IT             2023
#
#                   Current_Status  Internship Duration (Months)  Project  \
# 0                Editing Working                             6        3
# ...

# %%
pd.read_sql(" select * from College_students where Department Not in ('CSE')",engine)
# Out:
#      Student_ID Student_Name  Gender Department  Graduation_Year  \
# 0             4      Shruthi  Female         IT             2023
# 1             6      Keerthi  Female    AI & DS             2023
# 2             7        Surya    Male    AI & DS             2023
# 3             8        Sneha  Female         IT             2023
# 4            12    Aishwarya  Female         IT             2023
# ..          ...          ...     ...        ...              ...
# 309         495         Ravi    Male         IT             2023
# 310         497         Ravi    Male    AI & DS             2023
# 311         498      Lakshmi  Female         IT             2023
# 312         499        Vijay    Male    AI & DS             2023
# 313         500     Pavithra  Female    AI & DS             2023
#
#                   Current_Status  Internship Duration (Months)  Project  \
# 0              Marketing Working                             2        2
# ...

# %%
pd.read_sql("select * from College_Students where Student_ID between 100 And  200",engine)
# Out:
#      Student_ID Student_Name  Gender Department  Graduation_Year  \
# 0           100        Divya  Female        CSE             2023
# 1           101       Balaji    Male        CSE             2023
# 2           102      Shruthi  Female         IT             2023
# 3           103       Suresh    Male    AI & DS             2023
# 4           104       Sowmya  Female         IT             2023
# ..          ...          ...     ...        ...              ...
# 96          196        Meena  Female    AI & DS             2023
# 97          197         Amit    Male         IT             2023
# 98          198        Kavya  Female    AI & DS             2023
# 99          199        Arjun    Male        CSE             2023
# 100         200     Nandhini  Female        CSE             2023
#
#         Current_Status  Internship Duration (Months)  Project Location  \
# 0    Marketing Working                             4        1    India
# ...

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.26.4

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

print("NumPy Version :",np.__version__)
print("Pandas Version:",pd.__version__)
print("Matplotlib Version:",plt.__version__)
# Out:
# NumPy Version : 1.26.4
# Pandas Version: 2.2.3
# Matplotlib Version: 3.10.0

# %%
file_path = "Sales_Data_10K.xlsx "
df = pd.read_excel(file_path)

df.head()
# Out:
#     OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0  ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1  ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 2  ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3  ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 4  ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
#
#    SalesAmount  CostPrice  Profit Region    Segment    Team  \
# 0         1443      336.7   432.9  South  Corporate  Team A
# 1         2718      951.3   815.4   West  Corporate  Team C
# 2         1212      141.4   363.6  South  Corporate  Team D
# 3         5601     1306.9  1680.3  North  Wholesale  Team D
# 4         1310      183.4   393.0   West  Corporate  Team C
#
#        SalesExecutive
# 0   Sales Executive 1
# 1   Sales Executive 7
# 2  Sales Executive 34
# 3  Sales Executive 10
# 4   Sales Executive 6

# %%
df.shape
df.columns
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OrderID         10000 non-null  object
#  1   OrderDate       10000 non-null  datetime64[ns]
#  2   CustomerName    10000 non-null  object
#  3   Product         10000 non-null  object
#  4   Category        10000 non-null  object
#  5   Quantity        10000 non-null  int64
#  6   SalesAmount     10000 non-null  int64
#  7   CostPrice       10000 non-null  float64
#  8   Profit          10000 non-null  float64
#  9   Region          10000 non-null  object
#  10  Segment         10000 non-null  object
#  11  Team            10000 non-null  object
#  12  SalesExecutive  10000 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(8)
# memory usage: 1015.8+ KB
#                         OrderDate    Quantity   SalesAmount     CostPrice  \
# ...

# %%
df.isnull().sum()
# Out:
# OrderID           0
# OrderDate         0
# CustomerName      0
# Product           0
# Category          0
# Quantity          0
# SalesAmount       0
# CostPrice         0
# Profit            0
# Region            0
# Segment           0
# Team              0
# SalesExecutive    0
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
df.drop_duplicates(inplace = True)

# %%
df.columns
# Out:
# Index(['OrderID', 'OrderDate', 'CustomerName', 'Product', 'Category',
#        'Quantity', 'SalesAmount', 'CostPrice', 'Profit', 'Region', 'Segment',
#        'Team', 'SalesExecutive'],
#       dtype='object')

# %%
total_sales = np.sum(df['SalesAmount']) #total sales analysics 
avg_sales = np.mean(df['SalesAmount'])
max_sales = np.max(df['SalesAmount'])
min_sales = np.min(df['SalesAmount'])

print("Total Sales:",total_sales)
print("Average Sales:",avg_sales)
print("Max Sales:",max_sales)
print("Min Sales:",min_sales)
# Out:
# Total Sales: 56402283
# Average Sales: 5640.2283
# Max Sales: 20000
# Min Sales: 53

# %%
#sales by categorry
sales_by_product = df.groupby('Product') ['SalesAmount'].sum() 
sales_by_product.sort_values(ascending= False)
# Out:
# Product
# Monitor       6295836
# Laptop        5937423
# Smartphone    5750341
# Printer       5717514
# Webcam        5699478
# Tablet        5503892
# Headphones    5448320
# Mouse         5429214
# Speaker       5326767
# Keyboard      5293498
# Name: SalesAmount, dtype: int64

# %%
#Sales by region
sales_by_region = df.groupby('Region') ['SalesAmount'].sum()
sales_by_region
# Out:
# Region
# East     14132975
# North    13974387
# South    14601838
# West     13693083
# Name: SalesAmount, dtype: int64

# %%
#monthly /date wise sales
df['Date']= pd.to_datetime(df['OrderDate'])
df['Month']=df['OrderDate'].dt.month
monthly_sales= df.groupby('Month')['SalesAmount'].sum()
monthly_sales
# Out:
# Month
# 1     4882727
# 2     4379033
# 3     4889380
# 4     4347436
# 5     4799520
# 6     4836347
# 7     4882027
# 8     4993202
# 9     4608661
# 10    4621391
# 11    4369153
# 12    4793406
# Name: SalesAmount, dtype: int64

# %%
#top 10 sales record
df.sort_values(by='SalesAmount',ascending = False).head(5)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 7050  ORD07051 2023-05-12  Customer 221     Monitor  Electronics        10
# 4923  ORD04924 2023-09-22  Customer 258  Smartphone  Electronics        10
# 1445  ORD01446 2023-11-19  Customer 297  Headphones  Accessories        10
# 6001  ORD06002 2024-01-22  Customer 400      Laptop  Electronics        10
# 3889  ORD03890 2023-05-07  Customer 187       Mouse  Accessories        10
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# 7050        20000     1400.0  6000.0  North     Retail  Team A
# 4923        19990     1399.3  5997.0  South  Wholesale  Team A
# 1445        19970     1397.9  5991.0  North     Online  Team C
# 6001        19960     1397.2  5988.0   East  Corporate  Team D
# 3889        19960     1397.2  5988.0   East     Online  Team B
#
#           SalesExecutive
# 7050   Sales Executive 1
# 4923  Sales Executive 24
# 1445   Sales Executive 5
# 6001  Sales Executive 25
# ...

# %%
#python basics variable & data types
company_name = 'ABC sales pvt ltd'  #string
avg_sales = df['SalesAmount'].mean()
is_active= True

print("company_name:",company_name)
print("Average Sales:",avg_sales)#float
print("Is Active:",is_active)#boolean
# Out:
# company_name: ABC sales pvt ltd
# Average Sales: 5640.2283
# Is Active: True

# %%
df = pd.read_excel("Sales_Data_10K.xlsx ")
df['OrderDate']=pd.to_datetime(df['OrderDate'])
df['Month'] =df ['OrderDate'].dt.month
df.head()
# Out:
#     OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0  ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1  ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 2  ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3  ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 4  ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
#
#    SalesAmount  CostPrice  Profit Region    Segment    Team  \
# 0         1443      336.7   432.9  South  Corporate  Team A
# 1         2718      951.3   815.4   West  Corporate  Team C
# 2         1212      141.4   363.6  South  Corporate  Team D
# 3         5601     1306.9  1680.3  North  Wholesale  Team D
# 4         1310      183.4   393.0   West  Corporate  Team C
#
#        SalesExecutive  Month
# 0   Sales Executive 1      1
# 1   Sales Executive 7     10
# 2  Sales Executive 34      4
# 3  Sales Executive 10      9
# ...

# %%
total_sales = np.sum(df['SalesAmount']) #total sales analysics 
avg_sales = np.mean(df['SalesAmount'])
max_sales = np.max(df['SalesAmount'])
min_sales = np.min(df['SalesAmount'])

print("Total Sales:",total_sales)
print("Average Sales:",avg_sales)
print("Max Sales:",max_sales)
print("Min Sales:",min_sales)
# Out:
# Total Sales: 56402283
# Average Sales: 5640.2283
# Max Sales: 20000
# Min Sales: 53

# %%
import matplotlib.pyplot as plt

sales_by_region = df.groupby("Region")['SalesAmount'].sum()

plt.figure
sales_by_region.plot(kind='bar')
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("SalesAmount")
plt.show()

# %%
import matplotlib.pyplot as plt

Monthly_sales = df.groupby("Month")['SalesAmount'].sum()

plt.figure

plt.plot(Monthly_sales.index,Monthly_sales.values)
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("SalesAmount")
plt.show()

# %%
import matplotlib.pyplot as plt

category_sales= df.groupby("Category")['SalesAmount'].sum()

plt.figure()
plt.pie(category_sales.values,
labels=category_sales.index,
autopct='%1.1f%%')
plt.title("Category-wise sales Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
top_products= (
    df.groupby('Product')['SalesAmount'].sum().sort_values(ascending = False).head()
)

plt.figure()
top_products.plot(kind='bar')
plt.title("Top 5 Products by Sales")
plt.xlabel("Product")
plt.ylabel("SalesAmount")
plt.show()

# %%
import pandas as pd
from sqlalchemy import create_engine

excel_file =""
df = pd.read_excel(excel_file)

print(df.head())

engine=create_engine(
"mysql+pymysql://root:2411@localhost/ri"
)


df.to_sql(
    name="sales",
    con=engine,
    if_exists="replace",
    index=False
)

print("excel data inserted successfully")

# %%
import pandas as pd
customer =pd.DataFrame(
    {
        'customerId':[1,2,3],
        'name':['alice','bob','den']
    }
)

orders = pd.DataFrame({
    'orderId':[101,102,103],
    'customerId':[1,2,3],
    'product':['shrit','pant','mat']
})

result =pd.merge(customer,orders,on='customerId',how='inner')
print("inner join:")
print(result)
# Out:
# inner join:
#    customerId   name  orderId product
# 0           1  alice      101   shrit
# 1           2    bob      102    pant
# 2           3    den      103     mat

# %%
file_path = "Sales_Data_10K.xlsx "
df = pd.read_excel(file_path)

df.head()
# Out:
#     OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0  ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1  ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 2  ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3  ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 4  ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
#
#    SalesAmount  CostPrice  Profit Region    Segment    Team  \
# 0         1443      336.7   432.9  South  Corporate  Team A
# 1         2718      951.3   815.4   West  Corporate  Team C
# 2         1212      141.4   363.6  South  Corporate  Team D
# 3         5601     1306.9  1680.3  North  Wholesale  Team D
# 4         1310      183.4   393.0   West  Corporate  Team C
#
#        SalesExecutive
# 0   Sales Executive 1
# 1   Sales Executive 7
# 2  Sales Executive 34
# 3  Sales Executive 10
# 4   Sales Executive 6

# %%
import pandas as pd
df = pd.read_excel("Sales_Data_10K.xlsx")
print(df.head())
# Out:
#     OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0  ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1  ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 2  ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3  ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 4  ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
#
#    SalesAmount  CostPrice  Profit Region    Segment    Team  \
# 0         1443      336.7   432.9  South  Corporate  Team A
# 1         2718      951.3   815.4   West  Corporate  Team C
# 2         1212      141.4   363.6  South  Corporate  Team D
# 3         5601     1306.9  1680.3  North  Wholesale  Team D
# 4         1310      183.4   393.0   West  Corporate  Team C
#
#        SalesExecutive
# 0   Sales Executive 1
# 1   Sales Executive 7
# 2  Sales Executive 34
# 3  Sales Executive 10
# 4   Sales Executive 6

# %%
# check dataset information
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OrderID         10000 non-null  object
#  1   OrderDate       10000 non-null  datetime64[ns]
#  2   CustomerName    10000 non-null  object
#  3   Product         10000 non-null  object
#  4   Category        10000 non-null  object
#  5   Quantity        10000 non-null  int64
#  6   SalesAmount     10000 non-null  int64
#  7   CostPrice       10000 non-null  float64
#  8   Profit          10000 non-null  float64
#  9   Region          10000 non-null  object
#  10  Segment         10000 non-null  object
#  11  Team            10000 non-null  object
#  12  SalesExecutive  10000 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(8)
# memory usage: 1015.8+ KB
# None

# %%
#checking missing values
print(df.isnull().sum())
# Out:
# OrderID           0
# OrderDate         0
# CustomerName      0
# Product           0
# Category          0
# Quantity          0
# SalesAmount       0
# CostPrice         0
# Profit            0
# Region            0
# Segment           0
# Team              0
# SalesExecutive    0
# dtype: int64

# %%
#total sales amount
total_sales=df["SalesAmount"].sum()
print("total:",total_sales )
# Out:
# total: 56402283

# %%
#total sales amount
total_sales=df["SalesAmount"].max()
print("total:",total_sales )
# Out:
# total: 20000

# %%
# top 5 product by sales
top_product = df.groupby("Product")["SalesAmount"].sum().sort_values(ascending=False).head(5)
print(top_product)
# Out:
# Product
# Monitor       6295836
# Laptop        5937423
# Smartphone    5750341
# Printer       5717514
# Webcam        5699478
# Name: SalesAmount, dtype: int64

# %%
#region wise sales
region_sales = df.groupby("Region")["SalesAmount"].sum()
print(region_sales)
# Out:
# Region
# East     14132975
# North    13974387
# South    14601838
# West     13693083
# Name: SalesAmount, dtype: int64

# %%
#highest profit order
high_profit = df.loc[df["Profit"].idxmax()]
print(high_profit)
# Out:
# OrderID                      ORD07051
# OrderDate         2023-05-12 00:00:00
# CustomerName             Customer 221
# Product                       Monitor
# Category                  Electronics
# Quantity                           10
# SalesAmount                     20000
# CostPrice                      1400.0
# Profit                         6000.0
# Region                          North
# Segment                        Retail
# Team                           Team A
# SalesExecutive      Sales Executive 1
# Name: 7050, dtype: object

# %%
#covert orderdate to datetime
df["OrderDate"] = pd.to_datetime(df["OrderDate"])
print(df.dtypes)
# Out:
# OrderID                   object
# OrderDate         datetime64[ns]
# CustomerName              object
# Product                   object
# Category                  object
# Quantity                   int64
# SalesAmount                int64
# CostPrice                float64
# Profit                   float64
# Region                    object
# Segment                   object
# Team                      object
# SalesExecutive            object
# dtype: object

# %%
#monthly sales analysis
df["Month"]= df["OrderDate"].dt.month
monthly_sales = df.groupby("Month")["SalesAmount"].sum()
print(monthly_sales)
# Out:
# Month
# 1     4882727
# 2     4379033
# 3     4889380
# 4     4347436
# 5     4799520
# 6     4836347
# 7     4882027
# 8     4993202
# 9     4608661
# 10    4621391
# 11    4369153
# 12    4793406
# Name: SalesAmount, dtype: int64

# %%
#monthly sales analysis

monthly_sales = df.groupby("Month")["SalesAmount"].sum()
print(monthly_sales)
# Out:
# Month
# 1     4882727
# 2     4379033
# 3     4889380
# 4     4347436
# 5     4799520
# 6     4836347
# 7     4882027
# 8     4993202
# 9     4608661
# 10    4621391
# 11    4369153
# 12    4793406
# Name: SalesAmount, dtype: int64

# %%
#filtering question sales greater than 5000
high_sales=df["SalesAmount"]>5000
print(high_sales)
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 9995     True
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: SalesAmount, Length: 10000, dtype: bool

# %%
#electroinc category only
electronics = df[df["Category"] == "Electronics"]
print(electronics)
# Out:
#        OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0     ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1     ORD00002 2023-10-25  Customer 236       Mouse  Electronics         2
# 2     ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3     ORD00004 2023-09-12  Customer 321    Keyboard  Electronics         3
# 4     ORD00005 2023-03-08  Customer 196    Keyboard  Electronics         5
# ...        ...        ...           ...         ...          ...       ...
# 9995  ORD09996 2023-12-07  Customer 168  Headphones  Electronics        10
# 9996  ORD09997 2023-12-03  Customer 221     Speaker  Electronics         5
# 9997  ORD09998 2024-01-28  Customer 114      Laptop  Electronics         5
# 9998  ORD09999 2023-06-25  Customer 257      Laptop  Electronics         6
# 9999  ORD10000 2023-08-21  Customer 500  Headphones  Electronics         4
#
#       SalesAmount  CostPrice  Profit Region    Segment    Team  \
# ...

# %%
#region wise sales chat
import matplotlib.pyplot as plt
region_sales = df.groupby("Region")["SalesAmount"].sum()
region_sales.plot(kind="bar")
plt.title("Region Wise Sales")
plt.show()

# %%
import numpy as np 
sales_array = df["SalesAmount"].to_numpy()
print(sales_array)
# Out:
# [1443 2718 1212 ... 2585 4170 1968]

# %%
mean_sales= np.mean(sales_array)
median_sales = np.median(sales_array)
std_sales = np.std(sales_array)

mean_sales,median_sales,std_sales
# Out:
# (5640.2283, 4448.5, 4544.214795471173)

# %%
1. Dataset Understanding

How many rows and columns are in the dataset?

What are the column names?

What are the data types of each column?

Are there any missing values?

✅ 2. Basic Statistics

What is the total sales amount?

What is the total profit?

What is the average sales amount?

What is the maximum and minimum sales amount?

✅ 3. Simple Filtering

Show all orders from the South region.

Show orders where Profit > 1000.

Show orders where Category = Electronics.

Count number of orders in each Region.

✅ 4. Basic Visualization

Plot total sales by Region (Bar Chart).

Plot sales trend for first 100 records (Line Chart).

Create histogram of SalesAmount.

🟡 INTERMEDIATE LEVEL QUESTIONS

Now we move to real data analyst level thinking 👇

✅ 5. GroupBy Analysis

Find total sales by Region.

Find total profit by Category.

Find average sales by Segment.

Which Team generated highest profit?

Which SalesExecutive generated highest sales?

✅ 6. Business Performance Questions

Which Region is most profitable?

Which Category gives highest average profit?

What is the profit margin?
(Profit / SalesAmount)

Which product is sold most (based on Quantity)?

Top 10 highest sales orders?

✅ 7. Correlation & Relationship Analysis

Is there correlation between CostPrice and Profit?

Is higher quantity giving higher profit?

Create correlation heatmap.

✅ 8. Time-Based Analysis

Convert OrderDate to datetime.

Find monthly sales trend.

Find year-wise profit.

Which month has highest sales?

✅ 9. Advanced Intermediate Thinking

Identify top 5 customers based on total purchase.

Find loss-making orders (if any).

Calculate profit margin by Region.

Compare Wholesale vs Corporate performance.

Create pivot table of Region vs Category.

# %%
import pandas as pd
df= pd.read_excel("Sales_Data_10K.xlsx")
df.head()
# Out:
#     OrderID  OrderDate  CustomerName     Product     Category  Quantity  \
# 0  ORD00001 2024-01-06  Customer 177  Smartphone  Electronics         3
# 1  ORD00002 2023-10-25  Customer 236       Mouse  Accessories         2
# 2  ORD00003 2023-04-10  Customer 400      Laptop  Electronics         6
# 3  ORD00004 2023-09-12  Customer 321    Keyboard  Accessories         3
# 4  ORD00005 2023-03-08  Customer 196    Keyboard  Accessories         5
#
#    SalesAmount  CostPrice  Profit Region    Segment    Team  \
# 0         1443      336.7   432.9  South  Corporate  Team A
# 1         2718      951.3   815.4   West  Corporate  Team C
# 2         1212      141.4   363.6  South  Corporate  Team D
# 3         5601     1306.9  1680.3  North  Wholesale  Team D
# 4         1310      183.4   393.0   West  Corporate  Team C
#
#        SalesExecutive
# 0   Sales Executive 1
# 1   Sales Executive 7
# 2  Sales Executive 34
# 3  Sales Executive 10
# 4   Sales Executive 6

# %%
df=pd.
